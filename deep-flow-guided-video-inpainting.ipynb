# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# Restart runtime using 'Runtime' -> 'Restart runtime...'

import os

# !apt-get update
# !pip install -r "/content/gdrive/My Drive/Colab Notebooks/requirements.txt"

# !pip install -r "/content/gdrive/My Drive/Colab Notebooks/Deep-Flow-Guided-Video-Inpainting-master/requirements.txt"

print('setup complete')
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:6 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:7 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:11 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:12 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease
# Hit:13 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Reading package lists... Done
# ...

# %%
# Remove CUDA completely
# !apt-get --purge remove cuda nvidia* libnvidia-*
# !dpkg -l | grep cuda- | awk '{print $2}' | xargs -n1 dpkg --purge
# !apt-get remove cuda-*
# !apt autoremove
# !apt-get update
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'nvidia-325-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-346-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-binary' for glob 'nvidia*'
# Note, selecting 'nvidia-331-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-304-updates-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-384-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-346-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-340-updates-uvm' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common' for glob 'nvidia*'
# Note, selecting 'nvidia-331-updates-uvm' for glob 'nvidia*'
# Note, selecting 'nvidia-cg-toolkit' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-390' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-410' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common-415' for glob 'nvidia*'
# ...

# %%
# Install CUDA 8
import os
os.chdir('/content')

# !wget https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1604/x86_64/cuda-repo-ubuntu1604_8.0.61-1_amd64.deb
# !dpkg -i --force-overwrite cuda-repo-ubuntu1604_8.0.61-1_amd64.deb
# !apt-get update
# !apt-get install cuda-8-0
# install will fail, need to force dpkg to overwrite the configuration file
# !wget http://archive.ubuntu.com/ubuntu/pool/main/m/mesa/libglx-mesa0_18.0.5-0ubuntu0~18.04.1_amd64.deb
# !dpkg -i --force-overwrite libglx-mesa0_18.0.5-0ubuntu0~18.04.1_amd64.deb
# !wget http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1604/x86_64/nvidia-410_410.48-0ubuntu1_amd64.deb
# !dpkg -i --force-overwrite nvidia-410_410.48-0ubuntu1_amd64.deb
# !apt --fix-broken install
# !apt-get install cuda-8-0
# Out:
# --2020-05-14 20:38:02--  https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1604/x86_64/cuda-repo-ubuntu1604_8.0.61-1_amd64.deb
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 152.199.39.144
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|152.199.39.144|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2690 (2.6K) [application/x-deb]
# Saving to: ‘cuda-repo-ubuntu1604_8.0.61-1_amd64.deb’
#
# cuda-repo-ubuntu160 100%[===================>]   2.63K  --.-KB/s    in 0s
#
# 2020-05-14 20:38:02 (66.9 MB/s) - ‘cuda-repo-ubuntu1604_8.0.61-1_amd64.deb’ saved [2690/2690]
#
# Selecting previously unselected package cuda-repo-ubuntu1604.
# (Reading database ... 119063 files and directories currently installed.)
# Preparing to unpack cuda-repo-ubuntu1604_8.0.61-1_amd64.deb ...
# Unpacking cuda-repo-ubuntu1604 (8.0.61-1) ...
# Setting up cuda-repo-ubuntu1604 (8.0.61-1) ...
#
# ...

# %%
# !export CUDA_HOME=/usr/local/cuda
# !export LD_LIBRARY_PATH=$CUDA_HOME/lib64:$LD_LIBRARY_PATH
# !export TORCH=/usr/local/lib/python3.6/dist-packages/torch

# %%
# !nvcc --version
# !python -c "import torch; print(torch.__version__)"
# !python -c "import torch; print(torch.cuda.is_available())"
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2016 NVIDIA Corporation
# Built on Tue_Jan_10_13:22:03_CST_2017
# Cuda compilation tools, release 8.0, V8.0.61
# 0.4.0
# True

# %%
#!add-apt-repository ppa:ubuntu-toolchain-r/test
#!apt-get update
# !apt-get install gcc-5 g++-5

# !ln -sf /usr/bin/gcc-5 /usr/local/cuda/bin/gcc
# !ln -sf /usr/bin/g++-5 /usr/local/cuda/bin/g++
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   cpp-5 gcc-5-base libasan2 libgcc-5-dev libisl15 libmpx0 libstdc++-5-dev
# Suggested packages:
#   gcc-5-locales g++-5-multilib gcc-5-doc libstdc++6-5-dbg gcc-5-multilib
#   libgcc1-dbg libgomp1-dbg libitm1-dbg libatomic1-dbg libasan2-dbg
#   liblsan0-dbg libtsan0-dbg libubsan0-dbg libcilkrts5-dbg libmpx0-dbg
#   libquadmath0-dbg libstdc++-5-doc
# The following NEW packages will be installed:
#   cpp-5 g++-5 gcc-5 gcc-5-base libasan2 libgcc-5-dev libisl15 libmpx0
#   libstdc++-5-dev
# 0 upgraded, 9 newly installed, 0 to remove and 47 not upgraded.
# Need to get 29.1 MB of archives.
# After this operation, 100 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 gcc-5-base amd64 5.5.0-12ubuntu1 [17.1 kB]
# ...

# %%
import os
os.chdir('/content/gdrive/My Drive/Colab Notebooks/video-object-removal-with-copy-paste-network/get_mask')
#
#!bash make.sh

os.chdir('/content/gdrive/My Drive/Colab Notebooks/video-object-removal-with-copy-paste-network/get_mask/utils/pyvotkit')
# !python setup.py build_ext --inplace

os.chdir('/content/gdrive/My Drive/Colab Notebooks/video-object-removal-with-copy-paste-network/get_mask/utils/pysot/utils')
# !python setup.py build_ext --inplace

# %%
import shutil

os.chdir('/content/gdrive/My Drive/Colab Notebooks/Deep-Flow-Guided-Video-Inpainting-master/models/FlowNet2_Models/correlation_package')

# !TORCH=$(python -c "import os; import torch; print(os.path.dirname(torch.__file__))")

os.chdir('/content/gdrive/My Drive/Colab Notebooks/Deep-Flow-Guided-Video-Inpainting-master/models/FlowNet2_Models/correlation_package/src')

# !echo "Compiling correlation kernels by nvcc..."

os.remove('/content/gdrive/My Drive/Colab Notebooks/Deep-Flow-Guided-Video-Inpainting-master/models/FlowNet2_Models/correlation_package/src/correlation_cuda_kernel.o')
shutil.rmtree('/content/gdrive/My Drive/Colab Notebooks/Deep-Flow-Guided-Video-Inpainting-master/models/FlowNet2_Models/correlation_package/_ext')

# !nvcc -c -o correlation_cuda_kernel.o correlation_cuda_kernel.cu -x cu -Xcompiler -fPIC -arch=sm_37

os.chdir('/content/gdrive/My Drive/Colab Notebooks/Deep-Flow-Guided-Video-Inpainting-master/models/FlowNet2_Models/correlation_package')

# !python build.py
# Out:
# Compiling correlation kernels by nvcc...

# %%
os.chdir('/content/gdrive/My Drive/Colab Notebooks/Deep-Flow-Guided-Video-Inpainting-master/models/FlowNet2_Models/resample2d_package')


# !TORCH=$(python -c "import os; import torch; print(os.path.dirname(torch.__file__))")

os.chdir('/content/gdrive/My Drive/Colab Notebooks/Deep-Flow-Guided-Video-Inpainting-master/models/FlowNet2_Models/resample2d_package/src')

# !echo "Compiling resample2d kernels by nvcc..."

os.remove('/content/gdrive/My Drive/Colab Notebooks/Deep-Flow-Guided-Video-Inpainting-master/models/FlowNet2_Models/resample2d_package/src/Resample2d_kernel.o')
shutil.rmtree('/content/gdrive/My Drive/Colab Notebooks/Deep-Flow-Guided-Video-Inpainting-master/models/FlowNet2_Models/resample2d_package/_ext')

# !nvcc -c -o Resample2d_kernel.o Resample2d_kernel.cu -x cu -Xcompiler -fPIC -arch=sm_37 -I /usr/local/lib/python3.6/dist-packages/torch/lib/include/TH -I /usr/local/lib/python3.6/dist-packages/torch/lib/include/THC

os.chdir('/content/gdrive/My Drive/Colab Notebooks/Deep-Flow-Guided-Video-Inpainting-master/models/FlowNet2_Models/resample2d_package')

# !python build.py
# Out:
# Compiling resample2d kernels by nvcc...

# %%
os.chdir('/content/gdrive/My Drive/Colab Notebooks/Deep-Flow-Guided-Video-Inpainting-master/models/FlowNet2_Models/channelnorm_package')


# !TORCH=$(python -c "import os; import torch; print(os.path.dirname(torch.__file__))")

os.chdir('/content/gdrive/My Drive/Colab Notebooks/Deep-Flow-Guided-Video-Inpainting-master/models/FlowNet2_Models/channelnorm_package/src')

# !echo "Compiling channelnorm kernels by nvcc..."

os.remove('/content/gdrive/My Drive/Colab Notebooks/Deep-Flow-Guided-Video-Inpainting-master/models/FlowNet2_Models/channelnorm_package/src/ChannelNorm_kernel.o')
shutil.rmtree('/content/gdrive/My Drive/Colab Notebooks/Deep-Flow-Guided-Video-Inpainting-master/models/FlowNet2_Models/channelnorm_package/_ext')

# !nvcc -c -o ChannelNorm_kernel.o ChannelNorm_kernel.cu -x cu -Xcompiler -fPIC -arch=sm_37 -I /usr/local/lib/python3.6/dist-packages/torch/lib/include/TH -I /usr/local/lib/python3.6/dist-packages/torch/lib/include/THC

os.chdir('/content/gdrive/My Drive/Colab Notebooks/Deep-Flow-Guided-Video-Inpainting-master/models/FlowNet2_Models/channelnorm_package')

# !python build.py
# Out:
# Compiling channelnorm kernels by nvcc...

# %%
# 1 TEST - tennis

# %%
os.chdir('/content/gdrive/My Drive/Colab Notebooks/video-object-removal-with-copy-paste-network')

#get mask

# !python demo.py --data data/DAVIS_example/JPEGImages/480p/tennis --mask_coord "294 114 172 236"
# Out:
# [2020-05-07 17:38:17,210-rk0-load_helper.py# 31] load pretrained model from cp/SiamMask_DAVIS.pth
# [2020-05-07 17:38:25,104-rk0-load_helper.py# 25] remove prefix 'module.'
# ...

# %%
# 2 TEST - human

# %%
os.chdir('/content/gdrive/My Drive/Colab Notebooks/video-object-removal-with-copy-paste-network')

#get mask

# !python demo.py --data data/DAVIS_example/JPEGImages/480p/human --mask_coord "334 355 25 61"
# Out:
# [2020-05-07 20:11:52,465-rk0-load_helper.py# 31] load pretrained model from cp/SiamMask_DAVIS.pth
# [2020-05-07 20:11:59,674-rk0-load_helper.py# 25] remove prefix 'module.'
# ...

# %%
# MAIN INPAINTING

# %%
os.chdir('/content/gdrive/My Drive/Colab Notebooks/video-object-removal-with-copy-paste-network/results/data/DAVIS_example/JPEGImages')

# !python '/content/gdrive/My Drive/Colab Notebooks/Deep-Flow-Guided-Video-Inpainting-master/tools/video_inpaint.py' --frame_dir "480p/tennis_frame" --MASK_ROOT "480p/tennis_mask" --img_size 512 768 --FlowNet2 --DFC --ResNet101 --Propagation --flow_root '/content/gdrive/My Drive/Colab Notebooks/Deep-Flow-Guided-Video-Inpainting-master/results/flow' --output_root_propagation '/content/gdrive/My Drive/Colab Notebooks/Deep-Flow-Guided-Video-Inpainting-master/results/' --pretrained_model_flownet2 "/content/gdrive/My Drive/Colab Notebooks/Deep-Flow-Guided-Video-Inpainting-master/pretrained_models/FlowNet2_checkpoint.pth.tar" --output_root '/content/gdrive/My Drive/Colab Notebooks/Deep-Flow-Guided-Video-Inpainting-master/results'
# Out:
# This Video has 67 Images
# The optical flow list has been generated: 480p/video_flow.txt
# ====> Loading /content/gdrive/My Drive/Colab Notebooks/Deep-Flow-Guided-Video-Inpainting-master/pretrained_models/FlowNet2_checkpoint.pth.tar
# 480p/tennis_frame/00000.jpg 480p/tennis_frame/00001.jpg 480p/Flow/00000.flo
# ['480p/tennis_frame/00000.jpg', '480p/tennis_frame/00001.jpg', '480p/Flow/00000.flo']
# ['480p/tennis_frame/00000.jpg']
# ['480p/tennis_frame/00001.jpg']
# ['480p/Flow/00000.flo']
# 480p/tennis_frame/00001.jpg 480p/tennis_frame/00002.jpg 480p/Flow/00001.flo
# ['480p/tennis_frame/00001.jpg', '480p/tennis_frame/00002.jpg', '480p/Flow/00001.flo']
# ['480p/tennis_frame/00000.jpg', '480p/tennis_frame/00001.jpg']
# ['480p/tennis_frame/00001.jpg', '480p/tennis_frame/00002.jpg']
# ['480p/Flow/00000.flo', '480p/Flow/00001.flo']
# 480p/tennis_frame/00001.jpg 480p/tennis_frame/00000.jpg 480p/Flow/00001.rflo
# ...

# %%
# 1 TEST - demo from Deep Flow

# %%
os.chdir('/content/gdrive/My Drive/Colab Notebooks/Deep-Flow-Guided-Video-Inpainting-master')

# !python 'tools/video_inpaint.py' --frame_dir "demo/frames" --MASK_ROOT "demo/masks" --img_size 512 832 --FlowNet2 --DFC --ResNet101 --Propagation --pretrained_model_flownet2 'pretrained_models/FlowNet2_checkpoint.pth.tar' --output_root '/content/gdrive/My Drive/Colab Notebooks/Deep-Flow-Guided-Video-Inpainting-master/results'

# %%
# 2 TEST - human

# %%
os.chdir('/content/gdrive/My Drive/Colab Notebooks/video-object-removal-with-copy-paste-network/results/data/DAVIS_example/JPEGImages')

# !python '/content/gdrive/My Drive/Colab Notebooks/Deep-Flow-Guided-Video-Inpainting-master/tools/video_inpaint.py' --frame_dir "480p/human_frame" --MASK_ROOT "480p/human_mask" --img_size 640 480 --FlowNet2 --DFC --ResNet101 --Propagation --pretrained_model_flownet2 '/content/gdrive/My Drive/Colab Notebooks/Deep-Flow-Guided-Video-Inpainting-master/pretrained_models/FlowNet2_checkpoint.pth.tar' --output_root '/content/gdrive/My Drive/Colab Notebooks/Deep-Flow-Guided-Video-Inpainting-master/results'
